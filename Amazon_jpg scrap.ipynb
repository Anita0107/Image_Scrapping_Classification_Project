# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver
from selenium.webdriver.common.by import By

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException

#Importing requests
import requests

# importing regex
import re

#importing warnings
import warnings

import os

# %%
PATH = 'C:\Program Files (x86)\chromedriver.exe' #extracting path of the webdriver
driver = webdriver.Chrome(r"C:\\Users\\rajbi\\Downloads\\chromedriver_win32\\chromedriver.exe")
# Out:
# C:\Users\rajbi\AppData\Local\Temp/ipykernel_12128/2307474941.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\\Users\\rajbi\\Downloads\\chromedriver_win32\\chromedriver.exe")

# %%
driver.get("https://www.amazon.in/")

time.sleep(2)

search_job=driver.find_element(By.XPATH,"//input[@class='nav-input nav-progressive-attribute']")  #search bar
search_job.send_keys("saree")

search_btn=driver.find_element(By.XPATH,"//div[@class='nav-right']//input[@class='nav-input nav-progressive-attribute']") #search button
search_btn.click()

time.sleep(2)

# %%
# scrape all product urls
product_urls = []
start=0
end=6
time.sleep(1)
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")    #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)
    
img_urls = []
img_data = []
for url in product_urls:
    driver.get(url)
    time.sleep(2)
    images = driver.find_elements_by_xpath("//div[@class='imgTagWrapper']/img")
    for image in images:
        source= image.get_attribute('src')
        if source is not None:
            if(source[0:4] == 'http'):
                img_urls.append(source)
# Out:
# C:\Users\rajbi\AppData\Local\Temp/ipykernel_12128/2204629657.py:7: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   url=driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')       #scraping urls
# C:\Users\rajbi\AppData\Local\Temp/ipykernel_12128/2204629657.py:10: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   nxt_button=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")    #scraping the list of buttons from the page
# C:\Users\rajbi\AppData\Local\Temp/ipykernel_12128/2204629657.py:19: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   images = driver.find_elements_by_xpath("//div[@class='imgTagWrapper']/img")

# %%
len(img_urls)
# Out:
# 354

# %%
for i in range(len(img_urls)):
    if i >= 310:
        break
    print("Downloading {0} of {1} images" .format(i, 310))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\rajbi\OneDrive\Documents\TRAIN_IMG\saree"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
file.close()

# %%
# Trouser

# %%
driver.get("https://www.amazon.in/")

time.sleep(2)

search_job=driver.find_element(By.XPATH,"//input[@class='nav-input nav-progressive-attribute']")  #search bar
search_job.send_keys("trousers for men")

search_btn=driver.find_element(By.XPATH,"//div[@class='nav-right']//input[@class='nav-input nav-progressive-attribute']") #search button
search_btn.click()

time.sleep(2)

# %%
# scrape all product urls
product_urls = []
start=0
end=5
time.sleep(2)
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")    #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)
    
trouser_img= []
img_data = []
for url in product_urls:
    driver.get(url)
    time.sleep(2)
    images = driver.find_elements_by_xpath("//div[@class='imgTagWrapper']/img")
    for image in images:
        source= image.get_attribute('src')
        if source is not None:
            if(source[0:4] == 'http'):
                trouser_img.append(source)
# Out:
# C:\Users\rajbi\AppData\Local\Temp/ipykernel_12128/19035087.py:7: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   url=driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')       #scraping urls
# C:\Users\rajbi\AppData\Local\Temp/ipykernel_12128/19035087.py:10: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   nxt_button=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")    #scraping the list of buttons from the page
# C:\Users\rajbi\AppData\Local\Temp/ipykernel_12128/19035087.py:19: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   images = driver.find_elements_by_xpath("//div[@class='imgTagWrapper']/img")

# %%
len(trouser_img)
# Out:
# 314

# %%
for i in range(len(trouser_img)):
    if i >= 310:
        break    
    print("Downloading {0} of {1} images" .format(i,310))
    response= requests.get(trouser_img[i])
    file = open(r"C:\Users\rajbi\OneDrive\Documents\TRAIN_IMG\trousers"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
file.close()

# %%
driver.get("https://www.amazon.in/")

time.sleep(2)

search_job=driver.find_element(By.XPATH,"//input[@class='nav-input nav-progressive-attribute']")  #search bar
search_job.send_keys("Jeans for men")

search_btn=driver.find_element(By.XPATH,"//div[@class='nav-right']//input[@class='nav-input nav-progressive-attribute']") #search button
search_btn.click()

time.sleep(2)

# %%
# scrape all product urls
product_urls = []
start=0
end=6
time.sleep(2)
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")    #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)
    
jeans_img = []
img_data = []
for url in product_urls:
    driver.get(url)
    time.sleep(2)
    images = driver.find_elements_by_xpath("//div[@class='imgTagWrapper']/img")
    for image in images:
        source= image.get_attribute('src')
        if source is not None:
            if(source[0:4] == 'http'):
                jeans_img.append(source)
# Out:
# C:\Users\rajbi\AppData\Local\Temp/ipykernel_12128/1290792592.py:7: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   url=driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')       #scraping urls
# C:\Users\rajbi\AppData\Local\Temp/ipykernel_12128/1290792592.py:10: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   nxt_button=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")    #scraping the list of buttons from the page
# C:\Users\rajbi\AppData\Local\Temp/ipykernel_12128/1290792592.py:19: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   images = driver.find_elements_by_xpath("//div[@class='imgTagWrapper']/img")

# %%
len(jeans_img)
# Out:
# 351

# %%
for i in range(len(jeans_img)):
    if i >= 310:
        break    
    print("Downloading {0} of {1} images" .format(i,310))
    response= requests.get(jeans_img[i])
    file = open(r"C:\Users\rajbi\OneDrive\Documents\TRAIN_IMG\jeans"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
file.close()
